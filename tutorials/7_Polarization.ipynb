# %% [markdown]
# # Polarization

# %% [markdown]
# 很多软件自带的功能可以计算PI和PA,如CASA中的immath，miriad中的impol等

# %%
# 导入Stokes Q 和 U 的fits图像
import astropy.io.fits as pf
import numpy as np
file_q = "../fits/g284.4800.na6.q.p.image.total.crop.fits"
file_u = "../fits/g284.4800.na6.u.p.image.total.crop.fits"
hdr = pf.getheader(file_q)
data_q = pf.getdata(file_q)
data_u = pf.getdata(file_u)

# %% [markdown]
# ## 计算偏振PI及误差

# %% [markdown]
# ### 计算PI

# %%
data_PI = np.sqrt(data_q **2 + data_u **2)
sigma_PI = 1e-3
coeff = 1.2 
coeff = 2.3
data_PI_bias1 = np.sqrt(data_q *2 + data_u *2 - coeff * sigma_PI **2)

# %% [markdown]
# ### 计算误差
#
# 根据10.1093/mnras/stab218的公式
#
# ![image.png](attachment:image.png)
# $$\rm \sigma_{flux} = \sqrt{}$$

# %% [markdown]
# ## 计算偏振位置角及误差

# %% [markdown]
# ## 计算偏振度及误差

# %% [markdown]
# fractional polarization or percentage of polarization, defined as:
#
# $$ p = PI/I $$
#
# uncertainty on the fractional polarization, $\sigma _{p}$:
#
# $$ \sigma _{p} = P/I \cdot \sqrt{(\sigma _P / P)^2  + (\sigma _I /I)^2}

# %% [markdown]
# ##  intrinsic Magnetic Field
