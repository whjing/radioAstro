# %% [markdown]
# 表格来源：http://snrcat.physics.umanitoba.ca/SNRdownload.php?

# %%
import pandas as pd
import os
os.system("pwd")
file_snr = "../cat/SNRcat20250115-SNR.csv"
# Out:
# /Users/jing/composite-snr/code

# %% [markdown]
# 导入csv格式文件
#
# 对于csv格式文件，默认分割符为`,`， 但我们所用的这个表格的分割符为`;`，并且设置`#`开头行为标注；第二行是列名`header=1`

# %%
df_snr = pd.read_csv(file_snr, sep=";", comment="#", header=1)
# 显示前十行
df_snr.head(10)
# Out:
#              G  id_uncertain id_new      id_alt                 id_old  \
# 0  G000.0+00.0           NaN    NaN  Sgr A East                    NaN
# 1  G000.1-00.1           NaN    NaN  G0.13-0.12                    NaN
# 2  G000.3+00.0           NaN    NaN         NaN   G0.33+0.04, G0.4+0.1
# 3  G000.9+00.1           NaN    NaN         NaN                    NaN
# 4  G001.0-00.1           NaN    NaN       Sgr D  G1.05-0.1, G1.05-0.15
# 5  G001.4-00.1           NaN    NaN         NaN                    NaN
# 6  G001.9+00.3           NaN    NaN         NaN                    NaN
# 7  G003.7-00.2           NaN    NaN         NaN            G003.8-00.3
# 8  G003.8+00.3           NaN    NaN         NaN                    NaN
# 9  G004.2-03.5           NaN    NaN         NaN                    NaN
#
#                             type  type_uncertain  \
# 0              thermal composite             NaN
# 1  thermal & plerionic composite             1.0
# 2                          shell             NaN
# 3            plerionic composite             NaN
# 4                          shell             NaN
# 5                          shell             NaN
# 6                          shell             NaN
# 7                          shell             NaN
# 8                          shell             1.0
# 9                          shell             NaN
#
#                                              context      remnant  SN_year  \
# 0  contains CXOGC J174545.5-285829 = the Cannonba...  eje,NS,PWN?      NaN
# 1                            contains PWN G0.13-0.11     eje?,PWN      NaN
# 2                                                NaN          eje      NaN
# 3           contains PSR J1747-2809 + PWN G0.87+0.08  eje,PSR,PWN      NaN
# 4  close to star forming region Sgr D and other S...          eje      NaN
# 5                                                NaN          eje      NaN
# 6                                                NaN          eje      NaN
# 7                                                NaN          eje      NaN
# 8                                                NaN          eje      NaN
# 9                                                NaN          eje      NaN
#
#   SN_association  age_min (yr)  age_max (yr)  distance_min (kpc)  \
# 0            NaN        1200.0       10000.0                8.00
# 1            NaN           NaN           NaN                 NaN
# 2            NaN           NaN      500000.0                8.34
# 3            NaN        1900.0        1900.0                8.34
# 4            NaN           NaN           NaN                8.00
# 5            NaN           NaN           NaN                 NaN
# 6            NaN         150.0         220.0                8.34
# 7            NaN           NaN           NaN                 NaN
# 8            NaN           NaN           NaN                3.85
# 9            NaN           NaN           NaN                 NaN
#
#    distance_max (kpc)  size_coarse (arcmin)  size_imprecise size_radio  \
# 0                8.34                   2.9             NaN  3.5'x2.5'
# 1                 NaN                   0.7             1.0        NaN
# 2                8.50                  11.0             1.0     15'x8'
# 3               10.00                   8.0             NaN         8'
# 4                8.34                   8.0             NaN         8'
# 5                 NaN                  10.0             NaN        10'
# 6                8.50                   1.5             NaN       1.5'
# 7                 NaN                  12.0             NaN    14'x11'
# 8                4.43                  18.0             NaN        18'
# 9                 NaN                  28.0             NaN        28'
#
#        size_X J2000_ra (hh:mm:ss) J2000_dec (dd:mm:ss)     J2000_from
# 0         NaN            17:45:44            -29:00:00  Green J coord
# 1  >40" x ~2"            17:46:30            -28:51:30  paper J coord
# 2         NaN            17:46:15            -28:38:00  Green J coord
# 3         NaN            17:47:21            -28:09:00  Green J coord
# 4         NaN            17:48:30            -28:09:00  Green J coord
# 5         NaN            17:49:39            -27:46:00  Green J coord
# 6         NaN            17:48:45            -27:10:00  Green J coord
# 7         NaN            17:55:26            -25:50:00  Green J coord
# 8         NaN            17:52:55            -25:28:00  Green J coord
# 9         NaN            18:08:55            -27:03:00  Green J coord

# %%
# 设置显示所有行列
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# 显示所有行
df_snr.head(5)
# Out:
#              G  id_uncertain id_new      id_alt                 id_old  \
# 0  G000.0+00.0           NaN    NaN  Sgr A East                    NaN
# 1  G000.1-00.1           NaN    NaN  G0.13-0.12                    NaN
# 2  G000.3+00.0           NaN    NaN         NaN   G0.33+0.04, G0.4+0.1
# 3  G000.9+00.1           NaN    NaN         NaN                    NaN
# 4  G001.0-00.1           NaN    NaN       Sgr D  G1.05-0.1, G1.05-0.15
#
#                             type  type_uncertain  \
# 0              thermal composite             NaN
# 1  thermal & plerionic composite             1.0
# 2                          shell             NaN
# 3            plerionic composite             NaN
# 4                          shell             NaN
#
#                                              context      remnant  SN_year  \
# 0  contains CXOGC J174545.5-285829 = the Cannonba...  eje,NS,PWN?      NaN
# 1                            contains PWN G0.13-0.11     eje?,PWN      NaN
# 2                                                NaN          eje      NaN
# 3           contains PSR J1747-2809 + PWN G0.87+0.08  eje,PSR,PWN      NaN
# 4  close to star forming region Sgr D and other S...          eje      NaN
#
#   SN_association  age_min (yr)  age_max (yr)  distance_min (kpc)  \
# 0            NaN        1200.0       10000.0                8.00
# 1            NaN           NaN           NaN                 NaN
# 2            NaN           NaN      500000.0                8.34
# 3            NaN        1900.0        1900.0                8.34
# 4            NaN           NaN           NaN                8.00
#
#    distance_max (kpc)  size_coarse (arcmin)  size_imprecise size_radio  \
# 0                8.34                   2.9             NaN  3.5'x2.5'
# 1                 NaN                   0.7             1.0        NaN
# 2                8.50                  11.0             1.0     15'x8'
# 3               10.00                   8.0             NaN         8'
# 4                8.34                   8.0             NaN         8'
#
#        size_X J2000_ra (hh:mm:ss) J2000_dec (dd:mm:ss)     J2000_from
# 0         NaN            17:45:44            -29:00:00  Green J coord
# 1  >40" x ~2"            17:46:30            -28:51:30  paper J coord
# 2         NaN            17:46:15            -28:38:00  Green J coord
# 3         NaN            17:47:21            -28:09:00  Green J coord
# 4         NaN            17:48:30            -28:09:00  Green J coord

# %%
# 显示列名
df_snr.columns
# Out:
# Index(['G', 'id_uncertain', 'id_new', 'id_alt', 'id_old', 'type',
#        'type_uncertain', 'context', 'remnant', 'SN_year', 'SN_association',
#        'age_min (yr)', 'age_max (yr)', 'distance_min (kpc)',
#        'distance_max (kpc)', 'size_coarse (arcmin)', 'size_imprecise',
#        'size_radio', 'size_X', 'J2000_ra (hh:mm:ss)', 'J2000_dec (dd:mm:ss)',
#        'J2000_from'],
#       dtype='object')

# %%
# 统计行数（第一行为标题行）
df_snr.shape[0]
# Out:
# 383

# %%
# 筛选type含"composite"的行
df_composite = df_snr[df_snr["type"].str.contains("plerionic composite")]
df_composite.head(10)
# Out:
#               G  id_uncertain id_new      id_alt                    id_old  \
# 1   G000.1-00.1           NaN    NaN  G0.13-0.12                       NaN
# 3   G000.9+00.1           NaN    NaN         NaN                       NaN
# 13  G005.4-01.2           1.0    NaN    Milne 56       G5.3-1.0, G5.27-0.9
# 25  G007.5-01.7           1.0    NaN         NaN                       NaN
# 28  G008.7-00.1           NaN    NaN       (W30)                  G8.6-0.1
# 37  G011.1+00.1           NaN    NaN         NaN               G11.18+0.11
# 40  G011.2-00.3           NaN    NaN         NaN                       NaN
# 45  G012.5+00.2           NaN    NaN         NaN               G12.58+0.22
# 47  G012.8-00.0           NaN    NaN         W33  G12.82-0.02, G12.83-0.02
# 53  G015.4+00.1           NaN    NaN         NaN               G15.42+0.18
#
#                              type  type_uncertain  \
# 1   thermal & plerionic composite             1.0
# 3             plerionic composite             NaN
# 13            plerionic composite             1.0
# 25  thermal & plerionic composite             NaN
# 28  thermal & plerionic composite             1.0
# 37            plerionic composite             1.0
# 40            plerionic composite             NaN
# 45            plerionic composite             1.0
# 47            plerionic composite             NaN
# 53            plerionic composite             1.0
#
#                                               context        remnant  SN_year  \
# 1                             contains PWN G0.13-0.11       eje?,PWN      NaN
# 3            contains PSR J1747-2809 + PWN G0.87+0.08    eje,PSR,PWN      NaN
# 13  offset PSR J1801-2451 = B1757-24 = the Duck + ...  eje,PSR?,PWN?      NaN
# 25  contains PWN G7.4-2.0 = Taz, close to PSR J180...        eje,PWN      NaN
# 28  inside W30 complex, PSR J1803-2137 = B1800-21 ...  eje,PSR?,PWN?      NaN
# 37  contains PSR J1809-1917 + PWN G11.09+0.08, clo...    eje,PSR,PWN      NaN
# 40  contains PSR J1811-1925 = the Turtle + PWN G11...    eje,PSR,PWN    386.0
# 45                                                NaN           eje?      NaN
# 47  close to W33 complex, contains PSR J1813-1749 ...  eje,PSR?,PWN?      NaN
# 53                                      contains PWN?       eje,PWN?      NaN
#
#    SN_association  age_min (yr)  age_max (yr)  distance_min (kpc)  \
# 1             NaN           NaN           NaN                 NaN
# 3             NaN        1900.0        1900.0                8.34
# 13            NaN           NaN           NaN                3.89
# 25            NaN       50000.0       50000.0                1.70
# 28            NaN       15000.0       28000.0                3.20
# 37            NaN           NaN           NaN                 NaN
# 40      suggested        1400.0        2400.0                3.70
# 45            NaN           NaN           NaN                 NaN
# 47            NaN        1200.0        1200.0                4.00
# 53            NaN        2500.0        8200.0                4.80
#
#     distance_max (kpc)  size_coarse (arcmin)  size_imprecise size_radio  \
# 1                  NaN                   0.7             1.0        NaN
# 3                 10.0                   8.0             NaN         8'
# 13                 5.2                  35.0             NaN        35'
# 25                 2.0                 120.0             1.0     ~2 deg
# 28                 6.0                  45.0             NaN        45'
# 37                 NaN                  11.0             NaN    12'x10'
# 40                 4.7                   4.0             NaN         4'
# 45                 NaN                   5.5             NaN      6'x5'
# 47                 NaN                   3.0             NaN         3'
# 53                 9.8                  15.0             NaN    15'x14'
#
#         size_X J2000_ra (hh:mm:ss) J2000_dec (dd:mm:ss)     J2000_from
# 1   >40" x ~2"            17:46:30            -28:51:30  paper J coord
# 3          NaN            17:47:21            -28:09:00  Green J coord
# 13         NaN            18:02:10            -24:54:00  Green J coord
# 25       8'x5'            18:09:00            -23:18:00   paper G name
# 28         NaN            18:05:30            -21:26:00  Green J coord
# 37        6.8'            18:09:47            -19:12:00  Green J coord
# 40         NaN            18:11:29            -19:25:25     NS J coord
# 45         NaN            18:12:14            -17:55:00  Green J coord
# 47         NaN            18:13:37            -17:49:00  Green J coord
# 53         NaN            18:18:02            -15:27:00  Green J coord

# %%
# 计数
df_composite.shape[0]
# Out:
# 48

# %%
# 检查type_uncertain列
df_snr["type_uncertain"].unique()
# Out:
# array([nan,  1.])

# %%
# 筛选type_uncertain为nan的行
df_composite_sure = df_composite[df_composite["type_uncertain"].isnull()]
# 计数
print(df_composite_sure.shape[0])
df_composite_sure.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 筛选type_uncertain为nan的行
# ----> 2 df_composite_sure = df_composite[df_composite["type_uncertain"].isnull()]
#       3 # 计数
#       4 print(df_composite_sure.shape[0])
#
# NameError: name 'df_composite' is not defined

# %%
# 筛选type_uncertain为1的行
df_composite_uncertain = df_composite[df_composite["type_uncertain"] == 1]
# 计数
print(df_composite_uncertain.shape[0])
df_composite_uncertain.head()
# Out:
# 21
#               G  id_uncertain id_new      id_alt               id_old  \
# 1   G000.1-00.1           NaN    NaN  G0.13-0.12                  NaN
# 13  G005.4-01.2           1.0    NaN    Milne 56  G5.3-1.0, G5.27-0.9
# 28  G008.7-00.1           NaN    NaN       (W30)             G8.6-0.1
# 37  G011.1+00.1           NaN    NaN         NaN          G11.18+0.11
# 45  G012.5+00.2           NaN    NaN         NaN          G12.58+0.22
#
#                              type  type_uncertain  \
# 1   thermal & plerionic composite             1.0
# 13            plerionic composite             1.0
# 28  thermal & plerionic composite             1.0
# 37            plerionic composite             1.0
# 45            plerionic composite             1.0
#
#                                               context        remnant  SN_year  \
# 1                             contains PWN G0.13-0.11       eje?,PWN      NaN
# 13  offset PSR J1801-2451 = B1757-24 = the Duck + ...  eje,PSR?,PWN?      NaN
# 28  inside W30 complex, PSR J1803-2137 = B1800-21 ...  eje,PSR?,PWN?      NaN
# 37  contains PSR J1809-1917 + PWN G11.09+0.08, clo...    eje,PSR,PWN      NaN
# 45                                                NaN           eje?      NaN
#
#    SN_association  age_min (yr)  age_max (yr)  distance_min (kpc)  \
# 1             NaN           NaN           NaN                 NaN
# 13            NaN           NaN           NaN                3.89
# 28            NaN       15000.0       28000.0                3.20
# 37            NaN           NaN           NaN                 NaN
# 45            NaN           NaN           NaN                 NaN
#
#     distance_max (kpc)  size_coarse (arcmin)  size_imprecise size_radio  \
# 1                  NaN                   0.7             1.0        NaN
# 13                 5.2                  35.0             NaN        35'
# 28                 6.0                  45.0             NaN        45'
# 37                 NaN                  11.0             NaN    12'x10'
# 45                 NaN                   5.5             NaN      6'x5'
#
#         size_X J2000_ra (hh:mm:ss) J2000_dec (dd:mm:ss)     J2000_from
# 1   >40" x ~2"            17:46:30            -28:51:30  paper J coord
# 13         NaN            18:02:10            -24:54:00  Green J coord
# 28         NaN            18:05:30            -21:26:00  Green J coord
# 37        6.8'            18:09:47            -19:12:00  Green J coord
# 45         NaN            18:12:14            -17:55:00  Green J coord

# %% [markdown]
# - 共有48个混合型超新星遗迹，其中27个尚待认证。

# %% [markdown]
# ## 绘制其在银道面坐标下的分布

# %%
import matplotlib.pyplot as plt
from astropy.coordinates import SkyCoord
import numpy as np
from astropy import units as u

# 遍历数据，直接转换为银道坐标 l 和 b
l_list = []
b_list = []

# %%
l = 15 * u.pc
t = 3 * u.yr
v = l/t
print(v)
print(v.to(u.km/u.s))
# Out:
# 5.0 pc / yr
# 4888961.108403945 km / s

# %%
for index, row in df_composite.iterrows():
    # 将 RA 和 Dec 解析为 SkyCoord 对象
    c = SkyCoord(row["J2000_ra (hh:mm:ss)"], 
                 row["J2000_dec (dd:mm:ss)"], 
                 frame="icrs", unit=(u.hourangle, u.deg))
    # 转换为银道坐标
    l_list.append(c.galactic.l.value)  
    b_list.append(c.galactic.b.value)  
    
plt.figure(figsize=(10, 6))
ax = plt.subplot(111)
ax.scatter(l_list, b_list, s=10, color="blue")
ax.grid(True, alpha=0.5)
# 只显示b在-10 10度间的
#ax.set_ylim(-10 * np.pi / 180, 10 * np.pi / 180)

# 添加标题和图例
#plt.title("Distribution of 48 Composite SNRs in Galactic Coordinates (Mollweide)", pad=20)

plt.show()

# %%
for index, row in df_composite.iterrows():

    c = SkyCoord(row["J2000_ra (hh:mm:ss)"], 
                 row["J2000_dec (dd:mm:ss)"], 
                 frame="icrs", unit=(u.hourangle, u.deg))
    
    # 转为弧度,转为 [-180°, 180°]

    l_list.append(np.radians(c.galactic.l.wrap_at(180 * u.deg).value))  # 转为 [-180°, 180°]
    b_list.append(np.radians(c.galactic.b.value))  # 转为弧度

plt.figure(figsize=(10, 6))
ax = plt.subplot(111, projection="mollweide")
ax.scatter(l_list, b_list, s=10, color="blue")
ax.grid(True, alpha=0.5)
ax.set_xticklabels(['150°', '120°', '90°', '60°', '30°', '0°', '-30°', '-60°', '-90°', '-120°', '-150°'])

plt.show()

# %% [markdown]
# ## 读取Green Catalog

# %% [markdown]
# 注：示例表格为旧版表格，需要更新为新版的

# %%
file_green = "../cat/greencat.csv"
df_green = pd.read_csv(file_green)
df_green.head()
# Out:
#        name    l    b        RA     Dec     size type  flux       s
# 0  G0.0+0.0  0.0  0.0  17 45 44  -29 00  3.5x2.5    S  100?    0.8?
# 1  G0.3+0.0  0.3  0.0  17 46 15  -28 38     15x8    S    22     0.6
# 2  G0.9+0.1  0.9  0.1  17 47 21  -28 09        8    C   18?  varies
# 3  G1.0-0.1  1.0 -0.1  17 48 30  -28 09        8    S    15    0.6?
# 4  G1.4-0.1  1.4 -0.1  17 49 39  -27 46       10    S    2?       ?

# %%
df_green_com = df_green[df_green["type"].str.contains("C")]
print(df_green_com.shape[0])
df_green_com.head()
# Out:
# 37
#          name     l    b        RA     Dec size type flux       s
# 2    G0.9+0.1   0.9  0.1  17 47 21  -28 09    8    C  18?  varies
# 13   G5.4-1.2   5.4 -1.2  18 02 10  -24 54   35   C?  35?    0.2?
# 18   G6.4-0.1   6.4 -0.1  18 00 30  -23 26   48    C  310  varies
# 34  G11.2-0.3  11.2 -0.3  18 11 27  -19 25    4    C   22     0.5
# 39  G12.5+0.2  12.5  0.2  18 12 14  -17 55  6x5   C?  0.6     0.4

# %% [markdown]
# ## 将两个表格合并

# %%
def normalize_g_name(g_name):
    parts = g_name[1:].split("+") if "+" in g_name else g_name[1:].split("-")
    l_part = parts[0].zfill(5)  # 填充到5位
    b_part = parts[1].zfill(4)
    return f"G{l_part}{'+' if '+' in g_name else '-'}{b_part}"

# 对两个文件中的G name进行标准化处理G
#df_composite["normalized_G"] = df_composite["G"].apply(normalize_g_name)
df_green_com["normalized_name"] = df_green_com["name"].apply(normalize_g_name)

# 合并两个DataFrame，基于规范化的G name 进行匹配
df_merge = pd.merge(df_composite, df_green_com, left_on="G", right_on="normalized_name", how="inner")
print(df_merge.shape[0])
# 输出匹配结果
df_merge.head()
# Out:
# 33
# /var/folders/5m/c475x_g94tqb0d5r3t8c3w7w0000gn/T/ipykernel_46549/2318243781.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_green_com["normalized_name"] = df_green_com["name"].apply(normalize_g_name)
#              G  id_uncertain id_new    id_alt                    id_old  \
# 0  G000.9+00.1           NaN    NaN       NaN                       NaN
# 1  G005.4-01.2           1.0    NaN  Milne 56       G5.3-1.0, G5.27-0.9
# 2  G011.2-00.3           NaN    NaN       NaN                       NaN
# 3  G012.5+00.2           NaN    NaN       NaN               G12.58+0.22
# 4  G012.8-00.0           NaN    NaN       W33  G12.82-0.02, G12.83-0.02
#
#                 type_x  type_uncertain  \
# 0  plerionic composite             NaN
# 1  plerionic composite             1.0
# 2  plerionic composite             NaN
# 3  plerionic composite             1.0
# 4  plerionic composite             NaN
#
#                                              context        remnant  SN_year  \
# 0           contains PSR J1747-2809 + PWN G0.87+0.08    eje,PSR,PWN      NaN
# 1  offset PSR J1801-2451 = B1757-24 = the Duck + ...  eje,PSR?,PWN?      NaN
# 2  contains PSR J1811-1925 = the Turtle + PWN G11...    eje,PSR,PWN    386.0
# 3                                                NaN           eje?      NaN
# 4  close to W33 complex, contains PSR J1813-1749 ...  eje,PSR?,PWN?      NaN
#
#   SN_association  age_min (yr)  age_max (yr)  distance_min (kpc)  \
# 0            NaN        1900.0        1900.0                8.34
# 1            NaN           NaN           NaN                3.89
# 2      suggested        1400.0        2400.0                3.70
# 3            NaN           NaN           NaN                 NaN
# 4            NaN        1200.0        1200.0                4.00
#
#    distance_max (kpc)  size_coarse (arcmin)  size_imprecise size_radio size_X  \
# 0                10.0                   8.0             NaN         8'    NaN
# 1                 5.2                  35.0             NaN        35'    NaN
# 2                 4.7                   4.0             NaN         4'    NaN
# 3                 NaN                   5.5             NaN      6'x5'    NaN
# 4                 NaN                   3.0             NaN         3'    NaN
#
#   J2000_ra (hh:mm:ss) J2000_dec (dd:mm:ss)     J2000_from       name     l  \
# 0            17:47:21            -28:09:00  Green J coord   G0.9+0.1   0.9
# 1            18:02:10            -24:54:00  Green J coord   G5.4-1.2   5.4
# 2            18:11:29            -19:25:25     NS J coord  G11.2-0.3  11.2
# 3            18:12:14            -17:55:00  Green J coord  G12.5+0.2  12.5
# 4            18:13:37            -17:49:00  Green J coord  G12.8-0.0  12.8
#
#      b        RA     Dec size type_y flux       s normalized_name
# 0  0.1  17 47 21  -28 09    8      C  18?  varies     G000.9+00.1
# 1 -1.2  18 02 10  -24 54   35     C?  35?    0.2?     G005.4-01.2
# 2 -0.3  18 11 27  -19 25    4      C   22     0.5     G011.2-00.3
# 3  0.2  18 12 14  -17 55  6x5     C?  0.6     0.4     G012.5+00.2
# 4 -0.0  18 13 37  -17 49    3     C?  0.8     0.5     G012.8-00.0

# %%
# 添加一列为物理尺度
df_merge["size_pc"] = df_merge["size_coarse (arcmin)"] * np.deg2rad(np.nanmean(df_merge['distance_min (kpc)']+df_merge['distance_max (kpc)'])/60) * 1e3
df_merge.head()
# Out:
#              G  id_uncertain id_new    id_alt                    id_old  \
# 0  G000.9+00.1           NaN    NaN       NaN                       NaN
# 1  G005.4-01.2           1.0    NaN  Milne 56       G5.3-1.0, G5.27-0.9
# 2  G011.2-00.3           NaN    NaN       NaN                       NaN
# 3  G012.5+00.2           NaN    NaN       NaN               G12.58+0.22
# 4  G012.8-00.0           NaN    NaN       W33  G12.82-0.02, G12.83-0.02
#
#                 type_x  type_uncertain  \
# 0  plerionic composite             NaN
# 1  plerionic composite             1.0
# 2  plerionic composite             NaN
# 3  plerionic composite             1.0
# 4  plerionic composite             NaN
#
#                                              context        remnant  SN_year  \
# 0           contains PSR J1747-2809 + PWN G0.87+0.08    eje,PSR,PWN      NaN
# 1  offset PSR J1801-2451 = B1757-24 = the Duck + ...  eje,PSR?,PWN?      NaN
# 2  contains PSR J1811-1925 = the Turtle + PWN G11...    eje,PSR,PWN    386.0
# 3                                                NaN           eje?      NaN
# 4  close to W33 complex, contains PSR J1813-1749 ...  eje,PSR?,PWN?      NaN
#
#   SN_association  age_min (yr)  age_max (yr)  distance_min (kpc)  \
# 0            NaN        1900.0        1900.0                8.34
# 1            NaN           NaN           NaN                3.89
# 2      suggested        1400.0        2400.0                3.70
# 3            NaN           NaN           NaN                 NaN
# 4            NaN        1200.0        1200.0                4.00
#
#    distance_max (kpc)  size_coarse (arcmin)  size_imprecise size_radio size_X  \
# 0                10.0                   8.0             NaN         8'    NaN
# 1                 5.2                  35.0             NaN        35'    NaN
# 2                 4.7                   4.0             NaN         4'    NaN
# 3                 NaN                   5.5             NaN      6'x5'    NaN
# 4                 NaN                   3.0             NaN         3'    NaN
#
#   J2000_ra (hh:mm:ss) J2000_dec (dd:mm:ss)     J2000_from       name     l  \
# 0            17:47:21            -28:09:00  Green J coord   G0.9+0.1   0.9
# 1            18:02:10            -24:54:00  Green J coord   G5.4-1.2   5.4
# 2            18:11:29            -19:25:25     NS J coord  G11.2-0.3  11.2
# 3            18:12:14            -17:55:00  Green J coord  G12.5+0.2  12.5
# 4            18:13:37            -17:49:00  Green J coord  G12.8-0.0  12.8
#
#      b        RA     Dec size type_y flux       s normalized_name     size_pc
# 0  0.1  17 47 21  -28 09    8      C  18?  varies     G000.9+00.1   24.748303
# 1 -1.2  18 02 10  -24 54   35     C?  35?    0.2?     G005.4-01.2  108.273827
# 2 -0.3  18 11 27  -19 25    4      C   22     0.5     G011.2-00.3   12.374152
# 3  0.2  18 12 14  -17 55  6x5     C?  0.6     0.4     G012.5+00.2   17.014459
# 4 -0.0  18 13 37  -17 49    3     C?  0.8     0.5     G012.8-00.0    9.280614

# %%
# 绘制物理尺度随年龄的分布
plt.figure(figsize=(10, 6))
# 筛选出年龄不为nan的行
df_merge_filter = df_merge[df_merge["age_min (yr)"].notnull()]
age = df_merge_filter["age_min (yr)"] / 1e3  # 转为 kyr
plt.scatter( df_merge_filter ["size_pc"],age, s=20, color="blue", alpha=0.5)
plt.xlabel("Size (pc)")
plt.ylabel("Age (kyr)")
plt.grid(True, alpha=0.5)
plt.show()

# %% [markdown]
# - 超新星遗迹的典型物理尺度和年龄大概是多少
# - 异常值是什么原因？
# - 距离和年龄都是通过什么方式得到的？

# %%
# 绘制谱指数的分布直方图
plt.figure(figsize=(10, 6))
# 筛选出不为varies的行，且不含问号的行

plt.hist(df_merge["s"], bins=5, color="blue", alpha=0.5)
plt.xlabel("Spectral Index")
plt.ylabel("Count")
plt.grid(True, alpha=0.5)
plt.show()

# %% [markdown]
# 可以看到，由于表格为字符格式，且包含了其他字符，无法绘制出想要的效果。

# %%
df_merge_filter = df_merge[(df_merge["s"] != "varies") & (~df_merge["s"].str.contains("\?"))]
df_merge_filter["s"] = df_merge_filter["s"].astype(float)
plt.hist(df_merge_filter["s"], bins=5, color="blue", alpha=0.5)
plt.xlabel("Spectral Index")
plt.ylabel("Count")
plt.grid(True, alpha=0.5)
plt.show()
# Out:
# /var/folders/5m/c475x_g94tqb0d5r3t8c3w7w0000gn/T/ipykernel_46549/2072563347.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merge_filter["s"] = df_merge_filter["s"].astype(float)

# %% [markdown]
# ## 工作
# - 整理Green catalog
# - 合并三张表格，找出snrcat和green cat中对composite snr归类的异同
# - 整理出一份混合型超新星遗迹的表格

# %% [markdown]
# ## 表格中包含的信息

# %% [markdown]
# name
# l
# b
# RA
# Dec
# # in radio
# size_pwn_min
# size_pwn_max
# size_shell_min
# size_shell_max
